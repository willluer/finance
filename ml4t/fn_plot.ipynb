# %%
from utils import *
import datetime as dt
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]

def portfolio_optimization_fn(allocations,df):
    cumulative_returns = compute_cumulative_return(df,allocations)
    dr = compute_daily_returns(cumulative_returns)
    sh = compute_sharpe_ratio(dr)
    return -sh[0]

tickers = ["GLD","NFLX"]
start_date = dt.datetime(2010,1,1)
end_date = dt.datetime(2010,12,31)

data = get_closing_prices(get_ticker_data(tickers,start_date,end_date),normalized=True)

# %%
# x = np.linspace(0,1,5)
# y = np.linspace(0,1,5)

# X, Y = np.meshgrid(x, y)
# Z = portfolio_optimization_f([])

# %%
# import numpy as np
# from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.pyplot as plt
# import random

# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# n = 100
# xs = [i for i in range(n) for _ in range(n)]
# ys = list(range(n)) * n
# zs = [portfolio_optimization_fn([x, y],data) for x,y in zip(xs,ys)]

# ax.scatter(xs, ys, zs)

# ax.set_xlabel('X Label')
# ax.set_ylabel('Y Label')
# ax.set_zlabel('Z Label')

# plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import random

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = y = np.arange(0.0, 1.0, 0.01)
X, Y = np.meshgrid(x, y)
zs = np.array([portfolio_optimization_fn([x, y],data) for x,y in zip(np.ravel(X), np.ravel(Y))])

Z = zs.reshape(X.shape)
print(Z)
ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# [[        nan -1.43298844 -1.43298844 ... -1.43298844 -1.43298844
#   -1.43298844]
#  [-2.41383075 -2.45231647 -2.49399889 ... -1.5598302  -1.55857292
#   -1.55734024]
#  [-2.41383075 -2.43018378 -2.45231647 ... -1.67886648 -1.6765238
#   -1.6742248 ]
#  ...
#  [-2.41383075 -2.41411175 -2.41439271 ... -2.45231647 -2.45279631
#   -2.45327622]
#  [-2.41383075 -2.41410888 -2.41438697 ... -2.45184166 -2.45231647
#   -2.45279141]
#  [-2.41383075 -2.41410607 -2.41438135 ... -2.4513766  -2.45184645
#   -2.45231647]]
# /Users/williamluer/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: UserWarning: Z contains NaN values. This may result in rendering artifacts.
